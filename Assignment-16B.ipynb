# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Layer,Lambda

# %%
data=pd.read_csv("gas_turbines.csv")
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
data.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
plt.figure(figsize = (10,10))
sns.heatmap(data.corr(),annot=True,cmap="viridis",linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
# Finding Categorical Data :
print("The AT column")
print(data['AT'].value_counts())
print()
print("The AP column")
print(data['AP'].value_counts())
print()
print("The AH column")
print(data['AH'].value_counts())
print()
print("The AFDP column")
print(data['AFDP'].value_counts())
print()
print("The GTEP column")
print(data['GTEP'].value_counts())
print()
print("The TIT column")
print(data['TIT'].value_counts())
print()
print("The TAT column")
print(data['TAT'].value_counts())
print()
print("The TEY column")
print(data['TEY'].value_counts())
print()
print("The CDP column")
print(data['CDP'].value_counts())
print()
print("The CO column")
print(data['CO'].value_counts())
print()
print("The NOX column")
print(data['NOX'].value_counts())
print()
# Out:
# The AT column
# 20.1350    5
# 25.9690    5
# 14.0430    5
# 20.1690    5
# 20.7200    5
#           ..
# 17.7090    1
# 17.2890    1
# 17.1100    1
# 17.2850    1
# 6.9279     1
# Name: AT, Length: 12086, dtype: int64
#
# The AP column
# 1011.80    129
# 1012.10    127
# 1011.90    121
# 1010.80    119
# 1013.60    118
#           ...
# 996.30       1
# 998.02       1
# 998.48       1
# 998.88       1
# 1029.80      1
# Name: AP, Length: 540, dtype: int64
#
# The AH column
# 100.140    31
# 100.150    29
# 100.110    28
# 100.120    24
# 100.130    19
#            ..
# 57.187      1
# 60.104      1
# 62.370      1
# 67.608      1
# 97.533      1
# Name: AH, Length: 12637, dtype: int64
#
# The AFDP column
# 4.5032    7
# 4.4361    6
# 3.8837    6
# 4.4273    6
# 4.2500    6
#          ..
# 4.5599    1
# 4.6085    1
# 4.5880    1
# 4.5110    1
# 3.4770    1
# Name: AFDP, Length: 11314, dtype: int64
#
# The GTEP column
# 25.487    9
# 25.552    9
# 24.308    9
# 24.288    9
# 24.361    9
#          ..
# 25.686    1
# 22.525    1
# 25.485    1
# 20.980    1
# 19.164    1
# Name: GTEP, Length: 8234, dtype: int64
#
# The TIT column
# 1100.0    761
# 1099.9    598
# 1100.1    592
# 1100.2    415
# 1099.8    368
#          ...
# 1036.0      1
# 1048.8      1
# 1024.6      1
# 1031.3      1
# 1037.7      1
# Name: TIT, Length: 706, dtype: int64
#
# The TAT column
# 550.01    270
# 550.00    268
# 550.04    266
# 550.03    253
# 549.98    252
#          ...
# 533.65      1
# 528.40      1
# 524.54      1
# 532.56      1
# 545.85      1
# Name: TAT, Length: 2340, dtype: int64
#
# The TEY column
# 133.74    150
# 133.78    148
# 133.67    143
# 133.76    142
# 133.79    127
#          ...
# 126.30      1
# 130.81      1
# 144.89      1
# 121.46      1
# 115.52      1
# Name: TEY, Length: 4207, dtype: int64
#
# The CDP column
# 12.165    26
# 12.122    25
# 11.806    22
# 12.126    22
# 11.934    22
#           ..
# 10.003     1
# 10.031     1
# 13.189     1
# 10.021     1
# 11.685     1
# Name: CDP, Length: 3611, dtype: int64
#
# The CO column
# 1.33180    5
# 1.31910    5
# 1.23980    5
# 1.48320    5
# 1.28460    4
#           ..
# 0.28912    1
# 1.76560    1
# 1.51170    1
# 1.94150    1
# 4.98160    1
# Name: CO, Length: 13096, dtype: int64
#
# The NOX column
# 60.380    103
# 56.644      6
# 66.012      6
# 61.579      6
# 66.702      5
#          ...
# 64.898      1
# 65.574      1
# 65.475      1
# 65.404      1
# 92.498      1
# Name: NOX, Length: 11996, dtype: int64

# %%
data.shape
# Out:
# (15039, 11)

# %%
# Defining Predictors and Target Variables :
predictors_1 = data.iloc[:,0:7]
predictors_2 = data.iloc[:,8:]
predictors = predictors_1.join(predictors_2)

target = data.iloc[:,7]

# %%
predictors
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  10.583  4.9816
#
#           NOX
# 0      82.722
# 1      82.776
# 2      82.468
# 3      82.670
# 4      82.311
# ...       ...
# 15034  79.559
# 15035  79.917
# 15036  90.912
# 15037  93.227
# 15038  92.498
#
# [15039 rows x 10 columns]

# %%
target
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
# Splitting data into Train and Test Data Set :
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(predictors,target,test_size=0.3,random_state=0)

# %%
import tensorflow as tf
ann = tf.keras.models.Sequential()

# %%
#input layer + 1st hidden layer
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))
#adding 2nd layer
ann.add(tf.keras.layers.Dense(units =6,activation='relu'))
#adding the output layer
ann.add(tf.keras.layers.Dense(units=1))


#Training the ANN
#compililng the ANN
ann.compile(optimizer='adam',loss = 'mean_squared_error')

# %%
history = ann.fit(x_train,y_train,batch_size=32, epochs= 100)
# Out:
# Epoch 1/100
# 329/329 [==============================] - 2s 3ms/step - loss: 4579.9595
# Epoch 2/100
# 329/329 [==============================] - 1s 3ms/step - loss: 169.2088
# Epoch 3/100
# 329/329 [==============================] - 1s 3ms/step - loss: 165.2907
# Epoch 4/100
# 329/329 [==============================] - 1s 3ms/step - loss: 160.1721
# Epoch 5/100
# 329/329 [==============================] - 1s 3ms/step - loss: 153.7440
# Epoch 6/100
# 329/329 [==============================] - 1s 3ms/step - loss: 145.2905
# Epoch 7/100
# 329/329 [==============================] - 1s 2ms/step - loss: 135.1268
# Epoch 8/100
# 329/329 [==============================] - 1s 4ms/step - loss: 122.7342
# Epoch 9/100
# 329/329 [==============================] - 1s 4ms/step - loss: 107.9784
# Epoch 10/100
# 329/329 [==============================] - 1s 3ms/step - loss: 90.6315
# Epoch 11/100
# 329/329 [==============================] - 1s 3ms/step - loss: 70.9844
# Epoch 12/100
# 329/329 [==============================] - 1s 3ms/step - loss: 50.4296
# Epoch 13/100
# 329/329 [==============================] - 1s 3ms/step - loss: 32.3182
# Epoch 14/100
# 329/329 [==============================] - 1s 3ms/step - loss: 19.9077
# Epoch 15/100
# 329/329 [==============================] - 1s 3ms/step - loss: 13.0636
# Epoch 16/100
# 329/329 [==============================] - 1s 3ms/step - loss: 9.4625
# Epoch 17/100
# 329/329 [==============================] - 1s 3ms/step - loss: 7.6388
# Epoch 18/100
# 329/329 [==============================] - 1s 3ms/step - loss: 6.2887
# Epoch 19/100
# 329/329 [==============================] - 1s 3ms/step - loss: 5.3545
# Epoch 20/100
# 329/329 [==============================] - 1s 3ms/step - loss: 4.5750
# Epoch 21/100
# 329/329 [==============================] - 1s 3ms/step - loss: 4.0600
# Epoch 22/100
# 329/329 [==============================] - 1s 3ms/step - loss: 3.4519
# Epoch 23/100
# 329/329 [==============================] - 1s 3ms/step - loss: 3.1475
# Epoch 24/100
# 329/329 [==============================] - 1s 3ms/step - loss: 2.7187
# Epoch 25/100
# 329/329 [==============================] - 1s 3ms/step - loss: 2.3717
# Epoch 26/100
# 329/329 [==============================] - 1s 4ms/step - loss: 2.2268
# Epoch 27/100
# 329/329 [==============================] - 2s 5ms/step - loss: 2.1119
# Epoch 28/100
# 329/329 [==============================] - 2s 5ms/step - loss: 2.0221
# Epoch 29/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.8133
# Epoch 30/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.6816
# Epoch 31/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.7172
# Epoch 32/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.5537
# Epoch 33/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.4934
# Epoch 34/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.5527
# Epoch 35/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.4831
# Epoch 36/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.4048
# Epoch 37/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.3319
# Epoch 38/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.3392
# Epoch 39/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.2821
# Epoch 40/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.2938
# Epoch 41/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.3160
# Epoch 42/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.3196
# Epoch 43/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.3207
# Epoch 44/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.2886
# Epoch 45/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.2444
# Epoch 46/100
# 329/329 [==============================] - 1s 5ms/step - loss: 1.2005
# Epoch 47/100
# 329/329 [==============================] - 1s 4ms/step - loss: 1.1249
# Epoch 48/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.2563
# Epoch 49/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1818
# Epoch 50/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1728
# Epoch 51/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1689
# Epoch 52/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1690
# Epoch 53/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1836
# Epoch 54/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1253
# Epoch 55/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1901
# Epoch 56/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1183
# Epoch 57/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1915
# Epoch 58/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1501
# Epoch 59/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1562
# Epoch 60/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0845
# Epoch 61/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1612
# Epoch 62/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0945
# Epoch 63/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1714
# Epoch 64/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1558
# Epoch 65/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1266
# Epoch 66/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0837
# Epoch 67/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.1456
# Epoch 68/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1372
# Epoch 69/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1515
# Epoch 70/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1006
# Epoch 71/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0780
# Epoch 72/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.1300
# Epoch 73/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1370
# Epoch 74/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1129
# Epoch 75/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.1399
# Epoch 76/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0987
# Epoch 77/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.1349
# Epoch 78/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1259
# Epoch 79/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0930
# Epoch 80/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1016
# Epoch 81/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1444
# Epoch 82/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0788
# Epoch 83/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0993
# Epoch 84/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0338
# Epoch 85/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.1728
# Epoch 86/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1020
# Epoch 87/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1237
# Epoch 88/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0654
# Epoch 89/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1571
# Epoch 90/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.0633
# Epoch 91/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0647
# Epoch 92/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0944
# Epoch 93/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0843
# Epoch 94/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0568
# Epoch 95/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.1323
# Epoch 96/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.1153
# Epoch 97/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.0602
# Epoch 98/100
# 329/329 [==============================] - 1s 2ms/step - loss: 1.2907
# Epoch 99/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0838
# Epoch 100/100
# 329/329 [==============================] - 1s 3ms/step - loss: 1.0572

# %%
pred_train = ann.predict(np.array(x_train))
pred_train = pd.Series([i[0] for i in pred_train])
pred_train
# Out:
# 329/329 [==============================] - 1s 2ms/step
# 0        123.966217
# 1        133.204086
# 2        133.988922
# 3        149.898453
# 4        133.765671
#             ...
# 10522    112.185822
# 10523    133.213394
# 10524    152.917068
# 10525    125.778252
# 10526    109.502953
# Length: 10527, dtype: float32

# %%
# evaluate the model
scores = ann.evaluate(predictors, target)
print("%s: %.2f%%" % (ann.metrics_names[0], scores*100))
# Out:
# 470/470 [==============================] - 1s 2ms/step - loss: 0.9420
# loss: 94.20%

# %%
data.describe().T
# Out:
#         count         mean        std          min          25%        50%  \
# AT    15039.0    17.764381   7.574323     0.522300    11.408000    18.1860
# AP    15039.0  1013.199240   6.410760   985.850000  1008.900000  1012.8000
# AH    15039.0    79.124174  13.793439    30.344000    69.750000    82.2660
# AFDP  15039.0     4.200294   0.760197     2.087400     3.723900     4.1862
# GTEP  15039.0    25.419061   4.173916    17.878000    23.294000    25.0820
# TIT   15039.0  1083.798770  16.527806  1000.800000  1079.600000  1088.7000
# TAT   15039.0   545.396183   7.866803   512.450000   542.170000   549.8900
# TEY   15039.0   134.188464  15.829717   100.170000   127.985000   133.7800
# CDP   15039.0    12.102353   1.103196     9.904400    11.622000    12.0250
# CO    15039.0     1.972499   2.222206     0.000388     0.858055     1.3902
# NOX   15039.0    68.190934  10.470586    27.765000    61.303500    66.6010
#
#             75%        max
# AT      23.8625    34.9290
# AP    1016.9000  1034.2000
# AH      90.0435   100.2000
# AFDP     4.5509     7.6106
# GTEP    27.1840    37.4020
# TIT   1096.0000  1100.8000
# TAT    550.0600   550.6100
# TEY    140.8950   174.6100
# CDP     12.5780    15.0810
# CO       2.1604    44.1030
# NOX     73.9355   119.8900

# %%
# Changing position of target column 'TEY'
Target = data['TEY']
#Drop the existing column
data.drop(labels=['TEY'], axis=1,inplace = True)
data.insert(0, 'Y', Target)

data = data.rename({'Y':'TEY'}, axis = 1)

data.head()
# Out:
#       TEY      AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP  \
# 0  114.70  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605
# 1  114.72  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598
# 2  114.71  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601
# 3  114.72  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606
# 4  114.72  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
data.corr()
# Out:
#            TEY        AT        AP        AH      AFDP      GTEP       TIT  \
# TEY   1.000000 -0.207495  0.146939 -0.110272  0.717995  0.977042  0.891587
# AT   -0.207495  1.000000 -0.412953 -0.549432 -0.099333 -0.049103  0.093067
# AP    0.146939 -0.412953  1.000000  0.042573  0.040318  0.078575  0.029650
# AH   -0.110272 -0.549432  0.042573  1.000000 -0.119249 -0.202784 -0.247781
# AFDP  0.717995 -0.099333  0.040318 -0.119249  1.000000  0.744251  0.627254
# GTEP  0.977042 -0.049103  0.078575 -0.202784  0.744251  1.000000  0.874526
# TIT   0.891587  0.093067  0.029650 -0.247781  0.627254  0.874526  1.000000
# TAT  -0.720356  0.338569 -0.223479  0.010859 -0.571541 -0.756884 -0.357320
# CDP   0.988473 -0.100705  0.131198 -0.182010  0.727152  0.993784  0.887238
# CO   -0.541751 -0.088588  0.041614  0.165505 -0.334207 -0.508259 -0.688272
# NOX  -0.102631 -0.600006  0.256744  0.143061 -0.037299 -0.208496 -0.231636
#
#            TAT       CDP        CO       NOX
# TEY  -0.720356  0.988473 -0.541751 -0.102631
# AT    0.338569 -0.100705 -0.088588 -0.600006
# AP   -0.223479  0.131198  0.041614  0.256744
# AH    0.010859 -0.182010  0.165505  0.143061
# AFDP -0.571541  0.727152 -0.334207 -0.037299
# GTEP -0.756884  0.993784 -0.508259 -0.208496
# TIT  -0.357320  0.887238 -0.688272 -0.231636
# TAT   1.000000 -0.744740  0.063404  0.009888
# CDP  -0.744740  1.000000 -0.520783 -0.169103
# CO    0.063404 -0.520783  1.000000  0.316743
# NOX   0.009888 -0.169103  0.316743  1.000000

# %%
#Feature Selection by using Mutual Information Feature Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

# %%
x = data.iloc[:,1:]
y = data.iloc[:,0]

# %%
# feature selection
def select_features(x_train, y_train, x_test):
    # configure to select all features
    fs = SelectKBest(score_func=mutual_info_regression, k='all')
    # learn relationship from training data
    fs.fit(x_train, y_train)
    # transform train input data
    x_train_fs = fs.transform(x_train)
    # transform test input data
    x_test_fs = fs.transform(x_test)
    return x_train_fs, x_test_fs, fs

# %%
# split into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=1)
# feature selection
x_train_fs, x_test_fs, fs = select_features(x_train, y_train, x_test)

# %%
# what are scores for the features
for i in range(len(fs.scores_)):
    print('Feature %d: %f' % (i, fs.scores_[i]))
# plot the scores
fig, ax = plt.subplots(figsize=(10, 6))
plt.bar([i for i in range(len(fs.scores_))], fs.scores_)
plt.show()
# Out:
# Feature 0: 0.403149
# Feature 1: 0.147191
# Feature 2: 0.091161
# Feature 3: 0.657324
# Feature 4: 1.590986
# Feature 5: 1.304498
# Feature 6: 0.911313
# Feature 7: 1.710127
# Feature 8: 0.506136
# Feature 9: 0.303163

# %%
x = data.drop(['TEY','AT','AP','AH','CO','NOX'], axis = 1)
y = data.iloc[:,0]

# %%
x
# Out:
#          AFDP    GTEP     TIT     TAT     CDP
# 0      3.5000  19.663  1059.2  550.00  10.605
# 1      3.4998  19.728  1059.3  550.00  10.598
# 2      3.4824  19.779  1059.4  549.87  10.601
# 3      3.4805  19.792  1059.6  549.99  10.606
# 4      3.4976  19.765  1059.7  549.98  10.612
# ...       ...     ...     ...     ...     ...
# 15034  3.5421  19.164  1049.7  546.21  10.400
# 15035  3.5059  19.414  1046.3  543.22  10.433
# 15036  3.4770  19.530  1037.7  537.32  10.483
# 15037  3.4486  19.377  1043.2  541.24  10.533
# 15038  3.4275  19.306  1049.9  545.85  10.583
#
# [15039 rows x 5 columns]

# %%
y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20)

# %%
#Artificial Neural Network Model - Backpropagation

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# create model
model = Sequential()
model.add(Dense(10, input_dim=5, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

# %%
# Fit the model
history=model.fit(x, y, validation_split=0.33, epochs=100, batch_size=40)
# Out:
# Epoch 1/100
# 252/252 [==============================] - 4s 9ms/step - loss: 18290.0273 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 2/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0332 - mse: 18290.0332 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 3/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0332 - mse: 18290.0332 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 4/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 5/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0332 - mse: 18290.0332 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 6/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0215 - mse: 18290.0215 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 7/100
# 252/252 [==============================] - 1s 6ms/step - loss: 18290.0293 - mse: 18290.0293 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 8/100
# 252/252 [==============================] - 1s 6ms/step - loss: 18290.0273 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 9/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0273 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 10/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 11/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0156 - mse: 18290.0156 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 12/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 13/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 14/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 15/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 16/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0312 - mse: 18290.0293 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 17/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0176 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 18/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0273 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 19/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0176 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 20/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0332 - mse: 18290.0332 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 21/100
# 252/252 [==============================] - 1s 6ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 22/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 23/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 24/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 25/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0312 - mse: 18290.0312 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 26/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 27/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 28/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 29/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0215 - mse: 18290.0195 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 30/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0293 - mse: 18290.0293 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 31/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0273 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 32/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0332 - mse: 18290.0332 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 33/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0273 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 34/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 35/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 36/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 37/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 38/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 39/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 40/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0332 - mse: 18290.0332 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 41/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 42/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 43/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0215 - mse: 18290.0195 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 44/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 45/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0215 - mse: 18290.0215 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 46/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0293 - mse: 18290.0293 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 47/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 48/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 49/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0176 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 50/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 51/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 52/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0273 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 53/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0176 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 54/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0215 - mse: 18290.0215 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 55/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0176 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 56/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 57/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 58/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 59/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 60/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0176 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 61/100
# 252/252 [==============================] - 1s 3ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 62/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0176 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 63/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0293 - mse: 18290.0293 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 64/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 65/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0215 - mse: 18290.0215 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 66/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0156 - mse: 18290.0156 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 67/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 68/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0195 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 69/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 70/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 71/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0293 - mse: 18290.0293 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 72/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 73/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 74/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 75/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0273 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 76/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0137 - mse: 18290.0137 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 77/100
# 252/252 [==============================] - 1s 3ms/step - loss: 18290.0176 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 78/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 79/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 80/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0332 - mse: 18290.0332 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 81/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 82/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0195 - mse: 18290.0195 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 83/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0273 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 84/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0195 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 85/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 86/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0215 - mse: 18290.0195 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 87/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0176 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 88/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 89/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0273 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 90/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0215 - mse: 18290.0215 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 91/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0293 - mse: 18290.0293 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 92/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0293 - mse: 18290.0293 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 93/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0176 - mse: 18290.0176 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 94/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0234 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 95/100
# 252/252 [==============================] - 2s 6ms/step - loss: 18290.0273 - mse: 18290.0273 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 96/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0234 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 97/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0234 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 98/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 99/100
# 252/252 [==============================] - 1s 5ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645
# Epoch 100/100
# 252/252 [==============================] - 1s 4ms/step - loss: 18290.0254 - mse: 18290.0254 - val_loss: 17380.0645 - val_mse: 17380.0645

# %%
# evaluate the model
scores = model.evaluate(x, y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 470/470 [==============================] - 1s 3ms/step - loss: 17989.7324 - mse: 17989.7324
# mse: 1798973.24%

# %%
#Hyper Parameter Tuning

# %%
X = data.drop(['TEY','AT','AP','AH','CO','NOX'], axis = 1)
Y = data.iloc[:,0]

# %%
X
# Out:
#          AFDP    GTEP     TIT     TAT     CDP
# 0      3.5000  19.663  1059.2  550.00  10.605
# 1      3.4998  19.728  1059.3  550.00  10.598
# 2      3.4824  19.779  1059.4  549.87  10.601
# 3      3.4805  19.792  1059.6  549.99  10.606
# 4      3.4976  19.765  1059.7  549.98  10.612
# ...       ...     ...     ...     ...     ...
# 15034  3.5421  19.164  1049.7  546.21  10.400
# 15035  3.5059  19.414  1046.3  543.22  10.433
# 15036  3.4770  19.530  1037.7  537.32  10.483
# 15037  3.4486  19.377  1043.2  541.24  10.533
# 15038  3.4275  19.306  1049.9  545.85  10.583
#
# [15039 rows x 5 columns]

# %%
Y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
# Standardization
from sklearn.preprocessing import StandardScaler
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe().T
# Out:
#      count          mean       std       min       25%       50%       75%  \
# 0  15039.0  3.810001e-16  1.000033 -2.779497 -0.626693 -0.018541  0.461220
# 1  15039.0  1.107344e-16  1.000033 -1.806771 -0.509146 -0.080757  0.422864
# 2  15039.0 -2.324212e-15  1.000033 -5.021933 -0.254051  0.296554  0.738249
# 3  15039.0  1.744899e-15  1.000033 -4.188141 -0.410115  0.571257  0.592868
# 4  15039.0  3.640356e-16  1.000033 -1.992416 -0.435434 -0.070119  0.431168
#
#         max
# 0  4.486233
# 1  2.871006
# 2  1.028678
# 3  0.662784
# 4  2.700105

# %%
#Tuning of All Hyperparameters

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam
from keras.layers import Dropout

# %%
# Splitting data into test data and train data

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 5,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['mse'])
    return model

# %%
# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_45812\2849873856.py:3: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0)

# %%
# Define the grid search parameters

batch_size = [10,20,40]
epochs = [10,50,100]
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# %%
# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# %%
# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,verbose = 10, scoring='neg_mean_squared_error')
grid_result = grid.fit(X, Y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
# Out:
# Fitting 5 folds for each of 8748 candidates, totalling 43740 fits
# [CV 1/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 3ms/step
# [CV 1/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=-1600.483 total time=  33.3s
# [CV 2/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 2ms/step
# [CV 2/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=-976.073 total time=  33.7s
# [CV 3/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 2ms/step
# [CV 3/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=-1743.610 total time=  29.9s
# [CV 4/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 3ms/step
# [CV 4/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=-1450.393 total time=  30.7s
# [CV 5/5; 1/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 2ms/step
# [CV 5/5; 1/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2;, score=-1132.946 total time=  30.4s
# [CV 1/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 3ms/step
# [CV 1/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4;, score=-1600.483 total time=  30.6s
# [CV 2/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 3ms/step
# [CV 2/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4;, score=-976.073 total time=  33.9s
# [CV 3/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 3ms/step
# [CV 3/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4;, score=-1743.610 total time=  34.4s
# [CV 4/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 2ms/step
# [CV 4/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4;, score=-1450.393 total time=  30.3s
# [CV 5/5; 2/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 2ms/step
# [CV 5/5; 2/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4;, score=-1132.946 total time=  31.9s
# [CV 1/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 1s 3ms/step
# [CV 1/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8;, score=-1600.483 total time=  33.8s
# [CV 2/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 2ms/step
# [CV 2/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8;, score=-976.073 total time=  34.9s
# [CV 3/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 2ms/step
# [CV 3/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8;, score=-1743.610 total time=  36.0s
# [CV 4/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 2ms/step
# [CV 4/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8;, score=-1450.393 total time=  33.8s
# [CV 5/5; 3/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 3ms/step
# [CV 5/5; 3/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8;, score=-1132.946 total time=  34.4s
# [CV 1/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 2ms/step
# [CV 1/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2;, score=-1600.483 total time=  33.7s
# [CV 2/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 1s 2ms/step
# [CV 2/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2;, score=-976.073 total time=  33.6s
# [CV 3/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 94/94 [==============================] - 0s 2ms/step
# [CV 3/5; 4/8748] END activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2;, score=-1743.610 total time=  34.8s
# [CV 4/5; 4/8748] START activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# C:\Users\Lenovo\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
